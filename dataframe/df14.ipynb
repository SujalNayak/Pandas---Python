# %%
import pandas as pd

# %%
dfx = pd.DataFrame({"Fruit": ["Apple", "Banana", "Cherry", "Orange"], "Vegitables": ["Carrot", "Potato", "Tomato", "Cucumber"], "MarketPrice": [100, 50, 150, 80]})
dfx
# Out:
#     Fruit Vegitables  MarketPrice
# 0   Apple     Carrot          100
# 1  Banana     Potato           50
# 2  Cherry     Tomato          150
# 3  Orange   Cucumber           80

# %%
dfy = pd.DataFrame({"Fruit": ["Apple", "Banana", "Cherry", "Grapes"], "Vegitables": ["Carrot", "Potato", "Tomato", "Spinach"], "ShopPrice": [100, 50, 150, 120]})
dfy
# Out:
#     Fruit Vegitables  ShopPrice
# 0   Apple     Carrot        100
# 1  Banana     Potato         50
# 2  Cherry     Tomato        150
# 3  Grapes    Spinach        120

# %%
x = pd.merge(dfx, dfy, on="Fruit", how="inner")
x
# Out:
#     Fruit Vegitables_x  MarketPrice Vegitables_y  ShopPrice
# 0   Apple       Carrot          100       Carrot        100
# 1  Banana       Potato           50       Potato         50
# 2  Cherry       Tomato          150       Tomato        150

# %%
x = pd.merge(dfx, dfy, on="Fruit", how="outer")
x
# Out:
#     Fruit Vegitables_x  MarketPrice Vegitables_y  ShopPrice
# 0   Apple       Carrot        100.0       Carrot      100.0
# 1  Banana       Potato         50.0       Potato       50.0
# 2  Cherry       Tomato        150.0       Tomato      150.0
# 3  Orange     Cucumber         80.0          NaN        NaN
# 4  Grapes          NaN          NaN      Spinach      120.0

# %%
x = pd.merge(dfx, dfy, on="Fruit", how="left")
x
# Out:
#     Fruit Vegitables_x  MarketPrice Vegitables_y  ShopPrice
# 0   Apple       Carrot          100       Carrot      100.0
# 1  Banana       Potato           50       Potato       50.0
# 2  Cherry       Tomato          150       Tomato      150.0
# 3  Orange     Cucumber           80          NaN        NaN

# %%
x = pd.merge(dfx, dfy, on="Fruit", how="right")
x
# Out:
#     Fruit Vegitables_x  MarketPrice Vegitables_y  ShopPrice
# 0   Apple       Carrot        100.0       Carrot        100
# 1  Banana       Potato         50.0       Potato         50
# 2  Cherry       Tomato        150.0       Tomato        150
# 3  Grapes          NaN          NaN      Spinach        120

# %%
x = pd.merge(dfx, dfy, on=["Fruit","Vegitables"], how="inner")
x
# Out:
#     Fruit Vegitables  MarketPrice  ShopPrice
# 0   Apple     Carrot          100        100
# 1  Banana     Potato           50         50
# 2  Cherry     Tomato          150        150

# %%
x = pd.merge(dfx, dfy, on=["Fruit","Vegitables"], how="outer")
x
# Out:
#     Fruit Vegitables  MarketPrice  ShopPrice
# 0   Apple     Carrot        100.0      100.0
# 1  Banana     Potato         50.0       50.0
# 2  Cherry     Tomato        150.0      150.0
# 3  Orange   Cucumber         80.0        NaN
# 4  Grapes    Spinach          NaN      120.0
