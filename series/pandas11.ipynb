# %% [markdown]
# Map

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = s.map(lambda x: x*2)
print(s)
# Out:
# 0    20
# 1    40
# 2    60
# 3    80
# dtype: int64
