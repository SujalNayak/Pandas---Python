# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s.sum())
# Out:
# 150

# %%
print(s.mean())
# Out:
# 30.0

# %%
print(s.max())
# Out:
# 50

# %%
print(s.min())
# Out:
# 10

# %%
print(s.std())
# Out:
# 15.811388300841896

# %%
print(s.var())
# Out:
# 250.0

# %%
print(s.count())
# Out:
# 5
