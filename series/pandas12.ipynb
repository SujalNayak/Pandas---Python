# %% [markdown]
# Str functions

# %%
import pandas as pd

# %%
s = pd.Series(["apple","banana","cherry",12])
print(s)
# Out:
# 0     apple
# 1    banana
# 2    cherry
# 3        12
# dtype: object

# %%
s = s.str.upper()
print(s)
# Out:
# 0     APPLE
# 1    BANANA
# 2    CHERRY
# 3       NaN
# dtype: object

# %%
s = s.str.contains("A")
print(s)
# Out:
# 0     True
# 1     True
# 2    False
# 3      NaN
# dtype: object

# %%
s = s.str.startswith("A")
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s = s.str.startswith("A")
#       2 print(s)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...
